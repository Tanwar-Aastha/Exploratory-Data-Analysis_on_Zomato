# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.express as px

# %%
data = pd.read_csv("C:/Users/aasth/Downloads/zomato.csv",encoding='Latin-1')

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# adding the country name with respect to the country code
country_code = pd.read_excel("C:/Users/aasth/Downloads/Country_Code.xlsx")
country_code
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# merging both the tables
final_data = pd.merge(data, country_code, on='Country Code',
                      how='left')

# %%
final_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# checking the shape of the dataset
print("This dataset has {} rows and {} columns".format(final_data.shape[0], final_data.shape[1]))
# Out:
# This dataset has 9551 rows and 22 columns

# %%
# checking the datatypes of the columns
final_data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
# checking for the presence of null values
final_data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
final_data[final_data['Cuisines'].isnull()]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
(final_data['Cuisines'].isnull().sum()/len(final_data['Cuisines']))*100
# Out:
# np.float64(0.09423097057899697)

# %% [markdown]
# The missing values in the cuisines column is having a percentage of 0.09. Since the percentage of null values is very less thus removing them from the data.

# %%
null_rows = final_data[final_data['Cuisines'].isnull()].index

# %%
null_rows
# Out:
# Index([84, 87, 94, 297, 328, 346, 368, 418, 455], dtype='int64')

# %%
final_data.drop(index=[84, 87, 94, 297, 328, 346, 368, 418, 455], inplace=True)

# %%
final_data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %% [markdown]
# **Exploratory data analysis**

# %% [markdown]
# **Top 5 countries having highest number of restaurants**

# %%
top_countries = final_data['Country'].value_counts().reset_index().head()
top_countries
# Out:
#           Country  count
# 0           India   8652
# 1   United States    425
# 2  United Kingdom     80
# 3          Brazil     60
# 4    South Africa     60

# %%
fig = px.pie(top_countries, values='count', names='Country',
             title='Top 5 countries having restaurants linked with zomato')

# getting the label and percentage in the pie chart
fig.update_traces(textinfo='label+percent', rotation=180)

fig.show()

# %% [markdown]
# From the above pie chart, we can visualize that India have 93.2% of the total restaurants that are linked with Zomato across the world followed by United states accounting 4.67% of the total restaurants.

# %% [markdown]
# **What is the rating distribution**

# %%
rating = final_data.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0: 'Rating count'})
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
plt.figure(figsize=(12,7))

sns.barplot(data=rating, x='Aggregate rating', y='Rating count',
            hue='Aggregate rating', palette='viridis')
plt.show()

# %% [markdown]
# We can observe that the greatest number of ratings received ranges from 3.0 to 3.8, which could be due to the small number of restaurants with high ratings. India has the most restaurants, and several are rated 3 to 4. So this could have an impact on our analysis.

# %%
rating_text_distribution = final_data.groupby(['Rating text','Rating color']).size().reset_index().rename(columns={0:'Rating count'})
rating_text_distribution
# Out:
#   Rating text Rating color  Rating count
# 0     Average       Orange          3734
# 1   Excellent   Dark Green           300
# 2        Good       Yellow          2096
# 3   Not rated        White          2148
# 4        Poor          Red           186
# 5   Very Good        Green          1078

# %%
fig = px.pie(rating_text_distribution, values='Rating count', names='Rating text',
             title='Rating Text Distribution',
             color_discrete_sequence=['orange','white',
                                      'yellow','lightgreen','darkgreen',
                                      'red'])
fig.update_traces(textinfo='label+percent', hoverinfo='value',
                  marker=dict(line=dict(color='black',width=2)))
fig.show()

# %% [markdown]
# From the above pie chart, we can visualize that 39.1% of the restaurants have average rating. And the percentage of 'Not rated' rataurants are also quite high i.e, 22.5%.

# %% [markdown]
# **Checking the countries that has the highest number of unrated restaurants**

# %%
not_rated_countries = final_data[final_data['Rating color'] == 'White'].groupby('Country').size().reset_index().rename(columns={0:'Rating count'})
not_rated_countries
# Out:
#           Country  Rating count
# 0          Brazil             5
# 1           India          2139
# 2  United Kingdom             1
# 3   United States             3

# %% [markdown]
# India is the country having highest not rated count. Means 99% of the restaurants with no rating are from India. The reason might be that Indians are still coming to the terms of online food ordering.

# %% [markdown]
# **Checking for the countries offering online deliveries**

# %%
final_data['Has Online delivery'].value_counts()
# Out:
# Has Online delivery
# No     7091
# Yes    2451
# Name: count, dtype: int64

# %%
online_delivery_country = final_data[final_data['Has Online delivery']=='Yes']['Country'].value_counts().reset_index()
online_delivery_country
# Out:
#   Country  count
# 0   India   2423
# 1     UAE     28

# %%
fig = px.bar(online_delivery_country, x='Country',y='count',
             text_auto=True,
             color='Country',
             title='Countries offering online delivery of food')
fig.update_traces(textfont_size=18)


fig.show()

# %% [markdown]
# From the above bar chart we can see that out of 14 countries only 2 countries have the online delivery option which are India having 2423 restaurants and UAE having only 28 restaurants.

# %% [markdown]
# **How many restaurants are there having high rating with the option of online delivery?**

# %%
temp_df = final_data.groupby(['Rating text','Has Online delivery']).size().reset_index().rename(columns={0:'count'})

# %%
fig = px.bar(temp_df, x='Rating text',y='count',color='Has Online delivery',
             barmode='group', text_auto=True,
             title='Rating of Restaurants having Online and Offline Food Delivery')


fig.show()

# %% [markdown]
# There are 39 out of 301 restaurants having Excellent rating and 96 out of 1079 restaurants are having 'Very good' rating which are offering online deliveries.

# %% [markdown]
# 87% of restaurants are there having excellent rating but are not offering online deliveries. Lets check the countries of those retaurants.

# %%
final_data[final_data['Rating text'].isin(['Excellent'])].groupby(['Has Online delivery','Country']).size()
# Out:
# Has Online delivery  Country
# No                   Australia          1
#                      Brazil            16
#                      India             80
#                      Indonesia          7
#                      New Zealand       12
#                      Phillipines       12
#                      Qatar              4
#                      South Africa      12
#                      Sri Lanka          2
#                      Turkey            10
#                      UAE               15
#                      United Kingdom    23
#                      United States     67
# Yes                  India             36
#                      UAE                3
# dtype: int64

# %%
excellent_rating_countries = final_data[final_data['Rating text'] == 'Excellent']

# %%
temp_df = excellent_rating_countries[excellent_rating_countries['Has Online delivery'] == 'No'].groupby('Country').size().reset_index().rename(columns={0:'count'})
temp_df = temp_df.sort_values(by='count',ascending=False)

# %%
fig = px.bar(temp_df, x='Country', y='count', text_auto=True,color_discrete_sequence=['darkviolet'],
             title='Countries having restaurants with excellent rating and are not offing online deliveries')
fig.show()

# %% [markdown]
# Based on then bar chart we can say that India has the maximum number of restaurants that get excellent rating but don't offer online delivery of food.

# %% [markdown]
# **Checking the restaurants in India not offering online deliveries but have excellent rating**

# %%
temp_df1 = excellent_rating_countries[excellent_rating_countries['Has Online delivery'] == 'No']

temp_df1 = temp_df1[temp_df1['Country'].isin(['India'])]

# %%
import plotly.express as px

temp_df1['scaled_votes'] = temp_df1['Votes']*20

# Assuming 'size_column' is a numerical column for the size of the markers.
fig = px.scatter_mapbox(temp_df1,
                        lat='Latitude',
                        lon='Longitude',
                        color='Locality Verbose',
                        size='scaled_votes',
                        color_discrete_sequence=px.colors.cyclical.IceFire,
                        size_max=30,
                        zoom=10,
                        title='Indian Restaurants not offering online food delivery but have excellent rating')

fig.update_layout(mapbox_style="carto-positron")
fig.show()

# %% [markdown]
# By visualizing the location of the Indian restaurants that are not offering online food delivery and are having excellent rating, this could be for a variety of reasons, such as the restaurant being small-scale and thus not having a sufficient profit margin when selling through Zomato, or the restaurant being large-scale.

# %% [markdown]
# **What are the type of cuisines offered by the restaurants which are rated excellent?**

# %%
excellent_cuisines = final_data[final_data['Rating text']=='Excellent']
excellent_cuisines = excellent_cuisines['Cuisines'].value_counts().reset_index().head(20)

# %%
excellent_cuisines
# Out:
#                                  Cuisines  count
# 0                                    Cafe      8
# 1                            North Indian      7
# 2                                 Italian      7
# 3                               Ice Cream      5
# 4                                  Indian      5
# 5                                 Seafood      5
# 6                                   Asian      4
# 7                   North Indian, Mughlai      4
# 8                                Desserts      4
# 9                                  Burger      3
# 10                               American      3
# 11  European, Mediterranean, North Indian      3
# 12                          Modern Indian      3
# 13                       Bakery, Desserts      3
# 14                  North Indian, Chinese      3
# 15     Mexican, American, Tex-Mex, Burger      3
# 16                                   Thai      3
# 17                   Indian, North Indian      3
# ...

# %%
sns.barplot(data=excellent_cuisines, y='Cuisines',x='count',hue='Cuisines', palette='viridis')
plt.title('Top 20 cuisines that have excellent rating')
plt.show()

# %% [markdown]
# **Which city in India has higher number of restaurants?**

# %%
indian_restaurants = final_data[final_data['Country']=='India'].groupby('City').size().reset_index().rename(columns={0:'count'})
indian_restaurants = indian_restaurants.sort_values(by='count',ascending=False).head(10)

# %%
fig = px.bar(indian_restaurants, x='count', y='City', text_auto=True,
             title='Top 10 Indian cities having highest restaurants')

# fig.update_traces(textinfo='values')

fig.show()

# %%
top_5_cities = final_data[(final_data['Country'] =='India')&(final_data['City'].isin(['New Delhi','Gurgaon',
                                                                       'Noida','Faridabad','Ghaziabad','Guwahati',
                                                                       'Lucknow','Bhubaneshwar','Ahmedabad','Amritsar']))]

# %%
# hover_data=["Aggregate rating","Restaurant Name","Average Cost for two","Price range", 'Rating text']

fig = px.scatter_mapbox(top_5_cities, lat='Latitude',lon='Longitude',
                        color='Locality Verbose',
                        size='Votes',
                        color_discrete_sequence=px.colors.cyclical.IceFire,
                        size_max=30,
                        zoom=10,
                        title='Top 5 Indian Cities having highest number of Restaurants')

fig.update_layout(mapbox_style="carto-positron")
fig.show()

# %% [markdown]
# **Bivariate Analysis**

# %%
temp_df = final_data[(final_data['Average Cost for two']<10000)&(final_data['Aggregate rating'] != 0)]

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(data=temp_df, x='Average Cost for two',
                y='Aggregate rating',hue='Aggregate rating',
                palette='viridis')
plt.title("The dependency of rating on the prices for two")
plt.show()

# %% [markdown]
# The above scatter plot build between Aggregate rating and Price distribution for two shows that maximum  number of restaurants lies in the range of 0-1000 and mximum rating are from 2.5 to 4.5.

# %% [markdown]
# **Finding the relation between the Aggregate rating and Votes**

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(data=final_data, x='Aggregate rating',
                y='Votes',hue='Aggregate rating', 
                palette='flare')
plt.title('Relationship between Votes and Aggregate rating')
plt.show()

# %% [markdown]
# The above scatter plot shows that the maximum number of ratings lie between 3.5 to 4.8 whereas the frequency of votes which they have received are in the range 0-2000.

# %% [markdown]
# **Checking the relation between the restaurant's rating and their table reservations**

# %%
box_plot = sns.boxplot(data=final_data, x='Has Table booking',
            y='Aggregate rating', hue='Has Table booking', palette='husl')

# printing the median in the boxplot
ax = box_plot.axes
lines = ax.get_lines()
categories = ax.get_xticks()

for cat in categories:
    # every 4th line at the interval of 6 is median line
    # 0 -> p25 1 -> p75 2 -> lower whisker 3 -> upper whisker 4 -> p50 5 -> upper extreme value
    y = round(lines[4+cat*6].get_ydata()[0],1) 

    ax.text(
        cat, 
        y, 
        f'{y}', 
        ha='center', 
        va='center', 
        fontweight='bold', 
        size=10,
        color='white',
        bbox=dict(facecolor='#445A64'))

box_plot.figure.tight_layout()

plt.title('The dependency of the rating on the availablity of table reservations')
plt.show()

# %% [markdown]
# Restaurants with table reservations have a rating of roughly 3.6, while those without have an average rating of around 3.1.
# Lower ratings for restaurants may be attributed to customers having to return due to a lack of a table, or they may have rated the restaurant lower just because it did not have table reservations. In comparison, individuals with table reservations are fewer in number and have a higher rating. This figure may be biased due to the small number of restaurants. Still, it appears that customers are better satisfied with eateries that accept table reservations. Customers tend to give high ratings to sophisticated restaurants for psychological reasons or because they are simply good. Because there are fewer eateries, one bad report can drastically lower the average.

# %% [markdown]
# **Checking the relation between rating and availabilty of delivery**

# %%
box_plot = sns.boxplot(data=final_data, x='Is delivering now',
            y='Aggregate rating', hue='Is delivering now')

ax = box_plot.axes
lines = ax.get_lines()
categories = ax.get_xticks()

for cat in categories:
    # every 4th line at the interval of 6 is median line
    # 0 -> p25 1 -> p75 2 -> lower whisker 3 -> upper whisker 4 -> p50 5 -> upper extreme value
    y = round(lines[4+cat*6].get_ydata()[0],1) 

    ax.text(
        cat, 
        y, 
        f'{y}', 
        ha='center', 
        va='center', 
        fontweight='bold', 
        size=10,
        color='white',
        bbox=dict(facecolor='#445A64'))

box_plot.figure.tight_layout()
plt.title('Rating of restaurants that are available of delivery')

plt.show()

# %% [markdown]
# From the above boxplot we can easy visualize that the restaurants that are open to deliveries have a rating of 3.4 whereas the restaurants which are not available for deliveries have a median rating of 3.2.

# %% [markdown]
# Since India is the most populous country with the most restaurants, Delhi has the most restaurants in the entire country. Thus, let us investigate the data relating to Delhi.

# %%
import plotly.graph_objects as go

# Filtering the data for city New Delhi
delhi = final_data[final_data['City']=='New Delhi']

# Creating the bar chart
fig = go.Figure(data=[go.Bar(
    x=delhi['Locality'].value_counts().head(10).index,
    y= delhi['Locality'].value_counts().head(10),
    marker=dict(color='lightgreen'),
    text=delhi['Locality'].value_counts().head(10),
    textposition='auto'
)])

# Adding the tilte, xlabel and ylabel to the chart
fig.update_layout(title='Top 10 localities in New Delhi',
                  xaxis_title='Locality',
                  yaxis_title='Frequency',
                  title_x=0.5  # Center the title
                  )  
fig.show()

# %% [markdown]
# Connaught Place has the most restaurants in New Delhi (122), followed by Rajouri Garden, which has 99. Other areas do not lag behind.

# %% [markdown]
# **Top 10 Cuisines available in New Delhi**

# %%
cuisine_value = delhi['Cuisines'].value_counts()
cuisine_label = delhi['Cuisines'].value_counts().index

fig = go.Figure(data=go.Pie(
    labels=cuisine_label[:10], values=cuisine_value[:10],
    textinfo='label+percent', insidetextorientation='radial'
))

fig.update_layout(
    title={'text':'Top 10 Cuisines available in New Delhi',
           'y':0.95,    # movig the title up
           'x':0.5,     # Center title
           'xanchor':'center',
           'yanchor':'top'},
           uniformtext_minsize=12,   # setting minimum font size for labels
           margin=dict(t=100, b=50, l=50, r=50)   #adjusting margins
)

fig.update_traces(
    textposition='inside',  # Positions the text inside the pie slices
    insidetextorientation='radial'  # Or 'horizontal' to prevent text overlap
)

fig.show()

# %% [markdown]
# **Restaurants accepting online deliveries in New delhi**

# %%
top_locality = delhi['Locality'].value_counts().head(10)

plt.figure(figsize=(10, 7))
sns.countplot(data=delhi[delhi['Locality'].isin(top_locality.index)], y='Locality', 
              hue='Has Online delivery', palette='Paired')
plt.title('Top 10 restaurants in new delhi accepting online food delivery')

plt.show()

# %% [markdown]
# **Which is the highest rated restaurant in New Delhi**

# %%
# Creating the bar chart
fig = go.Figure(data=[go.Bar(
    x=delhi['Restaurant Name'].value_counts(ascending=False).head(10).index,
    y= delhi['Restaurant Name'].value_counts(ascending=False).head(10),
    marker=dict(color='seagreen'),
    text=delhi['Restaurant Name'].value_counts(ascending=False).head(10),
    textposition='auto'
)])

# Adding the tilte, xlabel and ylabel to the chart
fig.update_layout(title='Highest Rated Restaurants in New Delhi',
                  xaxis_title='Locality',
                  yaxis_title='Frequency',
                  title_x=0.5  # Center the title
                  )  
fig.show()

# %% [markdown]
# The above bar chart shows that Cafe Coffee day is the highest rated restaurant/cafe in New Delhi followed by Domino's Pizza and Subway.

# %% [markdown]
# **Location of the highest rated restaurants in New Delhi**

# %%
highest_rating = delhi[delhi['Rating text']=='Excellent']

fig = px.scatter_mapbox(highest_rating, lat='Latitude',
                        lon='Longitude',
                        hover_name='City',
                        hover_data=['Restaurant Name','Aggregate rating'],
                        color='Locality Verbose',
                        size='Votes',
                        color_discrete_sequence=px.colors.cyclical.IceFire,
                        size_max=30,
                        zoom=10)

fig.update_layout(mapbox_style="carto-positron", 
                  title='Highest rated restaurant in New Delhi',
                  autosize=True,
                  hovermode='closest',
                  showlegend=False)

fig.show()

# %% [markdown]
# **FINAL CONCLUSIONS: -**
# - The dataset is skewed towards India and doesn’t represent the complete data of restaurants worldwide.
# - There is no relation between cost and rating. Some of the best-rated restaurants are low on cost and vice versa.
# - Most of the restaurants are in India, to be precise 93.2%, this is understandable since Zomato is an Indian Company.
# - Not rated count is very high, this may happen mainly because customers do not like to review after having their food. This is why Zomato asks the users to rate the restaurants after around 1 hour of food delivery. This may prompt the customers to appreciate the food they had. If they had to criticise, they would have done it already.
# - Clearly, among all the restaurants, orange rated(average)(2.5-3.4) is the most common frequent rating.
# - The highest number of ratings recieved is around 3.0 to 3.8, this may happen because the number of restaurants which have high rating is low in number. India has the most number of restaurants and many restaurants fall into the bucket of 3 to 4 rating range.
# - 87% of restaurants are there having excellent rating but are not offering online deliveries. There could be a number of reasons for this, like the restaurant being extremely large or tiny enough that they do not have a sufficient profit margin when selling through Zomato.
# - The maximum number of restaurants falls in the 0 - 1000 price range and 2.5 to 4.0 rating.
# - Delhi has a lot of restaurants listed on Zomato. Connaught place has over 120 restaurants listed.
